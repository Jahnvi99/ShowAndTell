# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/Colab Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
import pickle as pkl
with open('./datasets/features_dict_inception_icon.pkl', 'rb') as out:
  ficon_dict=pkl.load(out)

# %%
(ficon_dict['features'][0]).shape
# Out:
# (1, 2048)

# %%
print(ficon_dict['ids'].index('_art_m_monnoyer_flowers4.'))
# Out:
# 1752

# %%
import numpy
feat_dict ={'ids':[],'features':numpy.zeros(shape=(2461,2048))}

# %%
for i in range(len(ficon_dict['features'])):
  feat_dict['features'][i,:]= ficon_dict['features'][i][0]
  feat_dict['ids'].append(ficon_dict['ids'][i])

# %%
feat_dict
# Out:
# {'features': array([[0.17056696, 0.11619657, 1.94191372, ..., 1.01499355, 0.51949441,
#          0.91373366],
#         [0.30581579, 0.81609529, 0.5260734 , ..., 0.96877778, 0.54871255,
#          1.0845542 ],
#         [0.19322319, 0.07575253, 1.63467801, ..., 1.93849552, 0.23598053,
#          0.49031293],
#         ...,
#         [0.46970859, 0.88273317, 0.89042175, ..., 0.4636285 , 1.14395559,
#          0.4211854 ],
#         [0.09507981, 0.18026802, 2.5211966 , ..., 0.27922606, 0.26843268,
#          0.23856367],
#         [0.70205837, 0.02932248, 1.45045972, ..., 0.17803061, 0.10972184,
#          1.55304956]]),
#  'ids': ['_art_a_abbate_proserpi',
#   '_art_a_adriaens_stilfish',
#   '_art_a_adriaens_stillife',
#   '_art_a_adriaens_stiloyst',
#   '_art_a_aelst_deadbird',
#   '_art_a_aelst_hunting',
#   '_art_a_aelst_hunting2',
#   '_art_a_aelst_stilbask',
#   '_art_a_aelst_stilflow',
#   '_art_a_aelst_stilfrui',
#   '_art_a_aelst_stillfru',
#   '_art_a_aelst_stillif',
# ...

# %%
from pickle import dump, load
dump(feat_dict, open('./datasets/features_dict_resnext_icon.pkl', 'wb'))
